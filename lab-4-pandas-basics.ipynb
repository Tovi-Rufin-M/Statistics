# %% [markdown]
# # Numpy Basics <hr style="border:2px solid #ff0000"><hr>

# %% [markdown]
# <b>Tovi R. Macalisay</b>
# <br>Comp Tech Student

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# # data Frame

# %%
data = {
    "Name":['dan', 'tovi', 'rex'],
    "Age":[21, 22, 21],
    "Sex":['M','M','M']
}

# %%
#creating dataframe for dictionary
df = pd.DataFrame(data)
df
# Out:
#    Name  Age Sex
# 0   dan   21   M
# 1  tovi   22   M
# 2   rex   21   M

# %% [markdown]
# # Series

# %%
age_col = df['Age']
type(age_col)
# Out:
# pandas.core.series.Series

# %%
age_col
# Out:
# 0    21
# 1    22
# 2    21
# Name: Age, dtype: int64

# %%
df['Name']
# Out:
# 0     dan
# 1    tovi
# 2     rex
# Name: Name, dtype: object

# %% [markdown]
# # Descriptive Statistics

# %%
resistance = np.array([
    [10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11, 10.4, 3, 9.8],
    [10.1, 11, 9.1, 20, 9.2, 10.8, 9.9, 9.2, 9.1, 9.1, np.nan]
]).T
print(resistance)
# Out:
# [[10.6 10.1]
#  [ 9.1 11. ]
#  [ 9.3  9.1]
#  [ 9.8 20. ]
#  [10.5  9.2]
#  [10.4 10.8]
#  [ 9.5  9.9]
#  [11.   9.2]
#  [10.4  9.1]
#  [ 3.   9.1]
#  [ 9.8  nan]]

# %%
# Creating dataframe from numpy array
df = pd.DataFrame(resistance, columns=['Jaguar', 'Panther'])
print(df)
# Out:
#     Jaguar  Panther
# 0     10.6     10.1
# 1      9.1     11.0
# 2      9.3      9.1
# 3      9.8     20.0
# 4     10.5      9.2
# 5     10.4     10.8
# 6      9.5      9.9
# 7     11.0      9.2
# 8     10.4      9.1
# 9      3.0      9.1
# 10     9.8      NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Panther']
# Out:
# 0     10.1
# 1     11.0
# 2      9.1
# 3     20.0
# 4      9.2
# 5     10.8
# 6      9.9
# 7      9.2
# 8      9.1
# 9      9.1
# 10     NaN
# Name: Panther, dtype: float64

# %%
df['Jaguar']
# Out:
# 0     10.6
# 1      9.1
# 2      9.3
# 3      9.8
# 4     10.5
# 5     10.4
# 6      9.5
# 7     11.0
# 8     10.4
# 9      3.0
# 10     9.8
# Name: Jaguar, dtype: float64

# %%
# Summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   11 non-null     float64
#  1   Panther  10 non-null     float64
# dtypes: float64(2)
# memory usage: 308.0 bytes

# %%
df.isna()
# Out:
#     Jaguar  Panther
# 0    False    False
# 1    False    False
# 2    False    False
# 3    False    False
# 4    False    False
# 5    False    False
# 6    False    False
# 7    False    False
# 8    False    False
# 9    False    False
# 10   False     True

# %%
df.isna().sum()
# Out:
# Jaguar     0
# Panther    1
# dtype: int64

# %%
df.dropna()
# Out:
#    Jaguar  Panther
# 0    10.6     10.1
# 1     9.1     11.0
# 2     9.3      9.1
# 3     9.8     20.0
# 4    10.5      9.2
# 5    10.4     10.8
# 6     9.5      9.9
# 7    11.0      9.2
# 8    10.4      9.1
# 9     3.0      9.1

# %%
df['Panther'].fillna(df['Panther'].mean())
# Out:
# 0     10.10
# 1     11.00
# 2      9.10
# 3     20.00
# 4      9.20
# 5     10.80
# 6      9.90
# 7      9.20
# 8      9.10
# 9      9.10
# 10    10.75
# Name: Panther, dtype: float64

# %%
print(df)
# Out:
#     Jaguar  Panther
# 0     10.6     10.1
# 1      9.1     11.0
# 2      9.3      9.1
# 3      9.8     20.0
# 4     10.5      9.2
# 5     10.4     10.8
# 6      9.5      9.9
# 7     11.0      9.2
# 8     10.4      9.1
# 9      3.0      9.1
# 10     9.8      NaN

# %%
df.describe()
# Out:
#           Jaguar    Panther
# count  11.000000  10.000000
# mean    9.400000  10.750000
# std     2.204541   3.329081
# min     3.000000   9.100000
# 25%     9.400000   9.125000
# 50%     9.800000   9.550000
# 75%    10.450000  10.625000
# max    11.000000  20.000000

# %%
# median
jag_median = df['Jaguar'].median()
pan_median = df['Panther'].median()

# %%
print('jag_median ',jag_median,'\npan_median',pan_median)
# Out:
# jag_median  9.8
# pan_median 9.55

# %%
# Mode
jag_mode = df['Jaguar'].mode()
pan_mode = df['Panther'].mode()
type(jag_mode)
# Out:
# pandas.core.series.Series

# %%
print("jaguar mode: ")
for i in (jag_mode):
    print(i, "ohms")
# Out:
# jaguar mode:
# 9.8 ohms
# 10.4 ohms

# %%
print("panther mode: ")
for i in (pan_mode):
    print(i, "ohms")
# Out:
# panther mode:
# 9.1 ohms

# %%
# jaguar iqr
Q1 = df['Jaguar'].quantile(0.25)
Q3 = df['Jaguar'].quantile(0.75)
print(f'jaguar IQR = {Q3-Q1:.2f} ohms')
# Out:
# jaguar IQR = 1.05 ohms

# %%
# jaguar iqr
Q1 = df['Panther'].quantile(0.25)
Q3 = df['Panther'].quantile(0.75)
print(f'Panther IQR = {Q3-Q1:.2f} ohms')
# Out:
# Panther IQR = 1.50 ohms

# %% [markdown]
# # Bar Chart

# %%
jag_mean = df['Jaguar'].mean()
pan_mean = df['Panther'].mean()

plt.figure(figsize=(7,4))
plt.title('Average Resistance by Machine')
bars = plt.bar(['Jaguar','Panther'],[jag_mean,pan_mean],color="violet")
plt.ylabel('Resistance (ohms)')

#label
plt.bar_label(bars,padding=3)
plt.margins(y=0.3)
plt.show()

# %%
df = pd.read_excel('students.xlsx')
df.head(1000)
# Out:
#      Unnamed: 0             Unnamed: 1  \
# 0           NaN           PLEASE READ!
# 1           NaN  GENERAL INSTRUCTIONS:
# 2           NaN                    NaN
# 3           NaN                    NaN
# 4           NaN                    NaN
# ..          ...                    ...
# 995         NaN               DAIROCAS
# 996         NaN                 DALIDA
# 997         NaN                DALISAY
# 998         NaN                DALISAY
# 999         NaN                DALISAY
#
#                                             Unnamed: 2  \
# 0                                                  NaN
# 1    1. Search your name below and copy your TUP em...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                        JOHN JOSHUA
# 996                                          MA.CELINE
# 997                                  CHRISTOPHER BRIAN
# 998                                              LANZE
# 999                                       MERVILYN JOY
#
#                               Unnamed: 3  Unnamed: 4   Unnamed: 5  \
# 0                                    NaN         NaN          NaN
# 1                                    NaN         NaN          NaN
# 2                                    NaN         NaN          NaN
# 3                                    NaN         NaN          NaN
# 4                                    NaN         NaN          NaN
# ..                                   ...         ...          ...
# 995       dairocas.johnjoshua@tup.edu.ph         NaN  Tajanlangit
# 996           dalida.maceline@tup.edu.ph         NaN         Tajo
# 997  dalisay.christopherbrian@tup.edu.ph         NaN     Talagtag
# 998             dalisay.lanze@tup.edu.ph         NaN      Talaman
# 999       dalisay.mervilynjoy@tup.edu.ph         NaN     Talavera
#
#       Unnamed: 6                      Unnamed: 7
# 0            NaN                             NaN
# 1            NaN                             NaN
# 2            NaN                             NaN
# 3            NaN                             NaN
# 4            NaN                             NaN
# ..           ...                             ...
# 995        Micah    tajanlangit.micah@tup.edu.ph
# 996  Marsha Faye     tajo.marsha.faye@tup.edu.ph
# 997    Jun Carlo   talagtag.jun.carlo@tup.edu.ph
# 998   Yuan Peter   talaman.yuan.peter@tup.edu.ph
# 999   Danica Ace  talavera.danica.ace@tup.edu.ph
#
# [1000 rows x 8 columns]
