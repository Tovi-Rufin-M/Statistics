# %% [markdown]
# # Lists and Tuples <hr style="border:2px solid #ff0000"><hr>

# %% [markdown]
# <b>Tovi R. Macalisay</b>
# <br>Comp Tech Student

# %% [markdown]
# # Creating a List

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruits = ['apple', 'banana', 'grape']

# %%
mixed_list = [10, 'hello', 2.5, True]
mixed_list
# Out:
# [10, 'hello', 2.5, True]

# %% [markdown]
# # Indexing

# %%
numbers = [1,2,3,4,5]
numbers[2]
# Out:
# 3

# %%
numbers[-3]
# Out:
# 3

# %% [markdown]
# # Modifying Elements

# %%
fruits = ['apple','banana','grape']

# %%
fruits[0] = 'orange'
fruits
# Out:
# ['orange', 'banana', 'grape']

# %%
fruits[-2] = 'blueberry'
fruits
# Out:
# ['orange', 'blueberry', 'grape']

# %% [markdown]
# # Adding Elements

# %%
fruits = ['apple', 'banana', 'grape']

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
fruits.insert(1, 'blueberry')
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'grape', 'orange']

# %% [markdown]
# # Removing Elements

# %%
fruits = ['apple', 'banana', 'grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
'orange' in fruits
# Out:
# False

# %%
fruits.remove('banana')

# %%
fruits = ['apple', 'banana', 'grape']

# %%
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['banana', 'grape']

# %% [markdown]
# # sort() and sorted()

# %%
numbers = [3,1,5,4,2]
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [5, 4, 3, 2, 1]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # slicing

# %%
number=[3,5,1,2,2,3,3,7,8]
number
# Out:
# [3, 5, 1, 2, 2, 3, 3, 7, 8]

# %%
len(number)
# Out:
# 9

# %%
sub = number[1:5]
sub
# Out:
# [5, 1, 2, 2]

# %%
number[0:8:2]
# Out:
# [3, 1, 2, 3]

# %% [markdown]
# # tuple

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple[1] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 my_tuple[1] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple = (1,1,2,3,4,5)
my_tuple
# Out:
# (1, 1, 2, 3, 4, 5)
